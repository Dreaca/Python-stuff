# %%
import requests

response = requests.get("http://api.github.com/events")

print(response.status_code)

if response.status_code == 200:
    print("OK")
elif response.status_code == 404:
    print("Not Found")
# Out:
# 200
# OK

# %%
import requests

response = requests.get("http://api.github.com/events")

if response.status_code ==200:
    print("OK")

    print(response.headers)
# Out:
# OK
# {'Connection': 'keep-alive', 'Content-Length': '10867', 'Referrer-Policy': 'no-referrer-when-downgrade', 'Cache-Control': 'max-age=3600, s-maxage=14400, stale-while-revalidate=3600', 'x-powered-by': 'Next.js', 'ETag': '"15w7vxmyt5f12xv"', 'Content-Type': 'text/html; charset=utf-8', 'Content-Encoding': 'gzip', 'x-github-backend': 'Kubernetes', 'X-GitHub-Request-Id': 'DAD0:182E0A:1D6B02D:2877F2F:67738EE7', 'Accept-Ranges': 'bytes', 'Age': '595742', 'Via': '1.1 varnish, 1.1 varnish', 'Set-Cookie': 'show_cookie_banner=0;SameSite=Lax; Secure; Path=/, show_cookie_banner=0;SameSite=Lax; Secure; Path=/', 'Date': 'Tue, 07 Jan 2025 03:56:54 GMT', 'X-Served-By': 'cache-iad-kiad7000100-IAD, cache-sin-wsss1830031-SIN', 'X-Cache': 'HIT, MISS', 'X-Cache-Hits': '0, 0', 'Vary': 'Accept-Language, Accept-Encoding', 'Cross-Origin-Resource-Policy': 'cross-origin', 'Strict-Transport-Security': 'max-age=31536000', 'X-Fastly-Request-ID': '8e2fe12905344860ac1cb2264b0cf80a5506d8eb'}

# %%
import requests

response = requests.get("http://api.github.com/events")

if response.status_code ==200:
    print("OK")

    content_type = response.headers['Content-Type']

    print(content_type)
# Out:
# OK
# application/json; charset=utf-8

# %%
import requests

response = requests.get("http://api.github.com/events")

if response.status_code ==200:
    print("OK")

    print(response.text)
# Out:
# OK
# [{"id":"45314121312","type":"PushEvent","actor":{"id":142633134,"login":"stainless-app[bot]","display_login":"stainless-app","gravatar_id":"","url":"https://api.github.com/users/stainless-app[bot]","avatar_url":"https://avatars.githubusercontent.com/u/142633134?"},"repo":{"id":865343834,"name":"DataMini/asktable-python","url":"https://api.github.com/repos/DataMini/asktable-python"},"payload":{"repository_id":865343834,"push_id":22000059045,"size":1,"distinct_size":1,"ref":"refs/heads/generated","head":"6f04b1ec44bdb9e7e836be277d71d2595ed6d610","before":"de85ce18e72559516a542b9805261a5bcb134f04","commits":[{"sha":"6f04b1ec44bdb9e7e836be277d71d2595ed6d610","author":{"email":"142633134+stainless-app[bot]@users.noreply.github.com","name":"stainless-app[bot]"},"message":"chore: add missing isclass check (#104)","distinct":true,"url":"https://api.github.com/repos/DataMini/asktable-python/commits/6f04b1ec44bdb9e7e836be277d71d2595ed6d610"}]},"public":true,"created_at":"2025-01-07T03:58:30Z","org":{"id":135623384,"login":"DataMini","gravatar_id":"","url":"https://api.github.com/orgs/DataMini","avatar_url":"https://avatars.githubusercontent.com/u/135623384?"}},{"id":"45314121308","type":"PushEvent","actor":{"id":182077460,"login":"Klaudius-netizen","display_login":"Klaudius-netizen","gravatar_id":"","url":"https://api.github.com/users/Klaudius-netizen","avatar_url":"https://avatars.githubusercontent.com/u/182077460?"},"repo":{"id":913109180,"name":"Klaudius-netizen/jawabujianif3a","url":"https://api.github.com/repos/Klaudius-netizen/jawabujianif3a"},"payload":{"repository_id":913109180,"push_id":22000059060,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"19dadc3db628b39bcbe1f875dd15af78edb97914","before":"45e98868c6c1a870b1d622a9f7bf4eee2051a563","commits":[{"sha":"19dadc3db628b39bcbe1f875dd15af78edb97914","author":{"email":"jessenfallikbemi_2327250065@mhs.mdp.ac.id","name":"JessenFB"},"message":".","distinct":true,"url":"https://api.github.com/repos/Klaudius-netizen/jawabujianif3a/commits/19dadc3db628b39bcbe1f875dd15af78edb97914"}]},"public":true,"created_at":"2025-01-07T03:58:30Z"},{"id":"45314121300","type":"PushEvent","actor":{"id":172878918,"login":"dmartinj12","display_login":"dmartinj12","gravatar_id":"","url":"https://api.github.com/users/dmartinj12","avatar_url":"https://avatars.githubusercontent.com/u/172878918?"},"repo":{"id":901016840,"name":"dmartinj12/GWU-Bootcamp","url":"https://api.github.com/repos/dmartinj12/GWU-Bootcamp"},"payload":{"repository_id":901016840,"push_id":22000059019,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"580b21f7a67023a46407bbf0c3160e2906bf6de7","before":"96b9e1b009625b770582f44f28f14bafb477c3cf","commits":[{"sha":"580b21f7a67023a46407bbf0c3160e2906bf6de7","author":{"email":"martinjonesdawson@gmail.com","name":"Dawson Martin-Jones"},"message":"update","distinct":true,"url":"https://api.github.com/repos/dmartinj12/GWU-Bootcamp/commits/580b21f7a67023a46407bbf0c3160e2906bf6de7"}]},"public":true,"created_at":"2025-01-07T03:58:30Z"},{"id":"45314121284","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":850231388,"name":"lubowmehajucelili/dp_project","url":"https://api.github.com/repos/lubowmehajucelili/dp_project"},"payload":{"repository_id":850231388,"push_id":22000059036,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"4e4d3450ff74da5ba9464196d7ffb72e245a3856","before":"e7cb09cfcf37301a59a898875f8a6a7d1de382b4","commits":[{"sha":"4e4d3450ff74da5ba9464196d7ffb72e245a3856","author":{"email":"lubowmehajucelili@gmail.com","name":"lubowmehajucelili"},"message":"a commit a day keeps your girlfriend away","distinct":true,"url":"https://api.github.com/repos/lubowmehajucelili/dp_project/commits/4e4d3450ff74da5ba9464196d7ffb72e245a3856"}]},"public":true,"created_at":"2025- ...

# %%
import requests

url = 'https://httpbin.org/post'

data = {
    'username':'user',
    'password':'pass'
}

response = requests.post(url, data=data)

if response.status_code == 200:
    print("Login successful")
    print(response.text)
else:
    print("Login failed")
    print(response.status_code)
# Out:
# Login successful
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "password": "pass",
#     "username": "user"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "27",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-677caed7-141f843f172721ae4fb060af"
#   },
#   "json": null,
#   "origin": "45.121.88.134",
#   "url": "https://httpbin.org/post"
# }

# %%
import requests

url = "http://example.com/search"

params = {
    'q':'python',
    'category':'books'
}

response = requests.get(url,params=params)

print(response.url)

print(response.text)
# Out:
# http://example.com/search?q=python&category=books
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
#
# <body>
# <div>
#     <h1>Example Domain</h1>
#     <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>
#     <p><a href="https://www.iana.org/domains/example">More information...</a></p>
# </div>
# </body>
# </html>

# %%
import requests

url = 'https://httpbin.org/get'

username = 'user'
password = 'pass'

response = requests.get(url, auth=(username, password))

if response.status_code == 200:
    print("Login successful")
    print(response.text)
else:
    print("Login failed")
    print(response.status_code)
# Out:
# Login successful
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Authorization": "Basic dXNlcjpwYXNz",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-677cb5ef-32fd432737010d994e01cb86"
#   },
#   "origin": "45.121.88.134",
#   "url": "https://httpbin.org/get"
# }
